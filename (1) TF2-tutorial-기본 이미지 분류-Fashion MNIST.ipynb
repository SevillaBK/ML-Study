# %% [markdown]
# # 텐서플로 공식블로그 튜토리얼 : 기본 이미지 분류
#   - https://www.tensorflow.org/tutorials/keras/classification
#
# 이번 튜토리얼은 운동화, 셔츠, 가방 등 패션 관련 이미지를 분류하는 신경망 모델을 만들어보는 내용입니다.

# %%
# 라이브러리 불러오기
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2.2.0-rc2

# %% [markdown]
# # 패션MNIST 데이터셋 임포트하기

# %% [markdown]
# 패션MNIST 데이터셋은 10가지 Category로 나눌 수 있는 70,000개의 데이터로 이루어져있습니다.

# %% [markdown]
# ![alt text](https://tensorflow.org/images/fashion-mnist-sprite.png)
